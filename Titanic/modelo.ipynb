# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/IagoDAinette/InteligenciaArtificial/refs/heads/main/Titanic/titanic.csv'

# %%
dado = pd.read_csv(url)
dado.shape
# Out:
# (891, 12)

# %%
dado.T
